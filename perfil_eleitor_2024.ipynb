# %%
import pandas as pd

# %%
df_eleitor = pd.read_csv('dados/perfil_eleitor_secao_2024_BA.csv', sep=';', encoding='latin1')

df_eleitor.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO   NM_MUNICIPIO  \
# 0  13/09/2024   11:28:18         2024    BA         34134       CAMAÇARI
# 1  13/09/2024   11:28:18         2024    BA         33138     ALAGOINHAS
# 2  13/09/2024   11:28:18         2024    BA         34193  CAMPO FORMOSO
# 3  13/09/2024   11:28:18         2024    BA         38210        REMANSO
# 4  13/09/2024   11:28:18         2024    BA         36692       JUAZEIRO
#
#    NR_ZONA  NR_SECAO  NR_LOCAL_VOTACAO  \
# 0      170       207              1040
# 1      163       227              1465
# 2       53       355              2259
# 3       67       234              1597
# 4       47       277              1759
#
#                                     NM_LOCAL_VOTACAO  ...  \
# 0           COLEGIO ESTADUAL POLIVALENTE DE CAMACARI  ...
# 1         ESCOLA MUNICIPAL MIGUEL CALMON - PRÉDIO 02  ...
# 2                    ESCOLA MUNICIPAL ARMINDO SIMÕES  ...
# ...
